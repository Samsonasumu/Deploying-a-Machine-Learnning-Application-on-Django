# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
#df = pd.read_csv('/content/cancer patient data sets.csv')
df = pd.read_excel("/content/cancer patient data sets.xlsx")
df.head()
# Out:
#   Patient Id  Age  Gender  Air Pollution  Alcohol use  Dust Allergy  \
# 0         P1   33       1              2            4             5
# 1        P10   17       1              3            1             5
# 2       P100   35       1              4            5             6
# 3      P1000   37       1              7            7             7
# 4       P101   46       1              6            8             7
#
#    OccuPational Hazards  Genetic Risk  chronic Lung Disease  Balanced Diet  \
# 0                     4             3                     2              2
# 1                     3             4                     2              2
# 2                     5             5                     4              6
# 3                     7             6                     7              7
# 4                     7             7                     6              7
#
#    ...  Fatigue  Weight Loss  Shortness of Breath  Wheezing  \
# ...

# %%
df.columns
# Out:
# Index(['Patient Id', 'Age', 'Gender', 'Air Pollution', 'Alcohol use',
#        'Dust Allergy', 'OccuPational Hazards', 'Genetic Risk',
#        'chronic Lung Disease', 'Balanced Diet', 'Obesity', 'Smoking',
#        'Passive Smoker', 'Chest Pain', 'Coughing of Blood', 'Fatigue',
#        'Weight Loss', 'Shortness of Breath', 'Wheezing',
#        'Swallowing Difficulty', 'Clubbing of Finger Nails', 'Frequent Cold',
#        'Dry Cough', 'Snoring', 'Level'],
#       dtype='object')

# %%
df = df.drop(['Patient Id'], axis=1)
df = df[df['Level'] != 'Medium']

# %%
df.shape
# Out:
# (668, 24)

# %%
df.describe()
# Out:
#               Age      Gender  Air Pollution  Alcohol use  Dust Allergy  \
# count  668.000000  668.000000     668.000000   668.000000    668.000000
# mean    36.455090    1.399701       4.290419     4.744012      5.026946
# std     11.412772    0.490204       1.954374     2.588530      2.180572
# min     17.000000    1.000000       1.000000     1.000000      1.000000
# 25%     27.000000    1.000000       2.000000     2.000000      3.000000
# 50%     35.000000    1.000000       4.000000     5.000000      6.000000
# 75%     44.000000    2.000000       6.000000     7.000000      7.000000
# max     64.000000    2.000000       8.000000     8.000000      8.000000
#
#        OccuPational Hazards  Genetic Risk  chronic Lung Disease  \
# count            668.000000    668.000000            668.000000
# mean               4.901198      4.723054              4.586826
# std                2.141011      2.142511              1.925900
# ...

# %%
df.shape
# Out:
# (668, 24)

# %%
df.isnull().sum()
# Out:
# Age                         0
# Gender                      0
# Air Pollution               0
# Alcohol use                 0
# Dust Allergy                0
# OccuPational Hazards        0
# Genetic Risk                0
# chronic Lung Disease        0
# Balanced Diet               0
# Obesity                     0
# Smoking                     0
# Passive Smoker              0
# Chest Pain                  0
# Coughing of Blood           0
# Fatigue                     0
# Weight Loss                 0
# Shortness of Breath         0
# Wheezing                    0
# Swallowing Difficulty       0
# Clubbing of Finger Nails    0
# Frequent Cold               0
# Dry Cough                   0
# Snoring                     0
# Level                       0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Air Pollution', 'Alcohol use', 'Dust Allergy',
#        'OccuPational Hazards', 'Genetic Risk', 'chronic Lung Disease',
#        'Balanced Diet', 'Obesity', 'Smoking', 'Passive Smoker', 'Chest Pain',
#        'Coughing of Blood', 'Fatigue', 'Weight Loss', 'Shortness of Breath',
#        'Wheezing', 'Swallowing Difficulty', 'Clubbing of Finger Nails',
#        'Frequent Cold', 'Dry Cough', 'Snoring', 'Level'],
#       dtype='object')

# %%
renamed_vars = {
    'Air Pollution': 'air_pollution',
    'Alcohol use': 'alcohol_use',
    'Dust Allergy': 'dust_allergy',
    'OccuPational Hazards': 'occupational_hazards',
    'Genetic Risk': 'genetic_risk',
    'chronic Lung Disease': 'chronic_lung_disease',
    'Balanced Diet': 'balanced_diet',
    'Obesity': 'obesity',
    'Smoking': 'smoking'
}

df = df.rename(columns=renamed_vars)

print(df)
# Out:
#      Age  Gender  air_pollution  alcohol_use  dust_allergy  \
# 0     33       1              2            4             5
# 2     35       1              4            5             6
# 3     37       1              7            7             7
# 4     46       1              6            8             7
# 5     35       1              4            5             6
# ..   ...     ...            ...          ...           ...
# 995   44       1              6            7             7
# 996   37       2              6            8             7
# 997   25       2              4            5             6
# 998   18       2              6            8             7
# 999   47       1              6            5             6
#
#      occupational_hazards  genetic_risk  chronic_lung_disease  balanced_diet  \
# 0                       4             3                     2              2
# 2                       5             5                     4              6
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'air_pollution', 'alcohol_use', 'dust_allergy',
#        'occupational_hazards', 'genetic_risk', 'chronic_lung_disease',
#        'balanced_diet', 'obesity', 'smoking', 'Passive Smoker', 'Chest Pain',
#        'Coughing of Blood', 'Fatigue', 'Weight Loss', 'Shortness of Breath',
#        'Wheezing', 'Swallowing Difficulty', 'Clubbing of Finger Nails',
#        'Frequent Cold', 'Dry Cough', 'Snoring', 'Level'],
#       dtype='object')

# %%
#X = df[['Age', 'Gender', 'air_pollution', 'alcohol_use', 'dust_allergy',

 #      'occupational_hazards', 'genetic_risk', 'chronic_lung_disease',
  #     'balanced_diet', 'obesity', 'smoking']]
X = df[['Age', 'air_pollution', 'alcohol_use', 'genetic_risk', 'chronic_lung_disease']]

y = df['Level']

X.head()
# Out:
#    Age  air_pollution  alcohol_use  genetic_risk  chronic_lung_disease
# 0   33              2            4             3                     2
# 2   35              4            5             5                     4
# 3   37              7            7             6                     7
# 4   46              6            8             7                     6
# 5   35              4            5             5                     4

# %%
plt.figure(figsize=(40, 20))
heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True)
heatmap.set_title('Correlation Heatmap of the cancer variables', fontdict={'fontsize':12}, pad=12);
# Out:
# <ipython-input-38-30f9e120d5f0>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   heatmap = sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True)

# %% [markdown]
# ## DATA VISUALISATION

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'air_pollution', 'alcohol_use', 'dust_allergy',
#        'occupational_hazards', 'genetic_risk', 'chronic_lung_disease',
#        'balanced_diet', 'obesity', 'smoking', 'Passive Smoker', 'Chest Pain',
#        'Coughing of Blood', 'Fatigue', 'Weight Loss', 'Shortness of Breath',
#        'Wheezing', 'Swallowing Difficulty', 'Clubbing of Finger Nails',
#        'Frequent Cold', 'Dry Cough', 'Snoring', 'Level'],
#       dtype='object')

# %%
df['genetic_risk'].hist()
plt.xlabel('Genetic Risk')
plt.ylabel('Count')
plt.title('Genetic Risk Distribution')
plt.show()

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'air_pollution', 'alcohol_use', 'dust_allergy',
#        'occupational_hazards', 'genetic_risk', 'chronic_lung_disease',
#        'balanced_diet', 'obesity', 'smoking', 'Passive Smoker', 'Chest Pain',
#        'Coughing of Blood', 'Fatigue', 'Weight Loss', 'Shortness of Breath',
#        'Wheezing', 'Swallowing Difficulty', 'Clubbing of Finger Nails',
#        'Frequent Cold', 'Dry Cough', 'Snoring', 'Level'],
#       dtype='object')

# %%
# Create a scatter plot of two numerical columns
df.plot.scatter('genetic_risk', 'occupational_hazards')
plt.xlabel('risk')
plt.ylabel('OccuPational Hazards')
plt.title('genetic risk vs OccuPational Hazards')
plt.show()

# %%
# The number of views in each categorical basket using bars.
sns.countplot(data= df , x='Level',label="Count")
# Out:
# <Axes: xlabel='Level', ylabel='count'>

# %%
sns.histplot(df.Age,kde=True)
# Out:
# <Axes: xlabel='Age', ylabel='Count'>

# %% [markdown]
# ## LOGISTIC REGRESSION

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y,test_size=.20, random_state=0)

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression(solver='liblinear')
model.fit(X_train, y_train)
#LogisticRegression()
model.predict(X_test)
# Out:
# array(['High', 'Low', 'High', 'Low', 'High', 'High', 'High', 'Low', 'Low',
#        'Low', 'High', 'High', 'High', 'Low', 'Low', 'Low', 'High', 'High',
#        'Low', 'High', 'Low', 'High', 'High', 'High', 'Low', 'High',
#        'High', 'Low', 'Low', 'Low', 'Low', 'Low', 'High', 'Low', 'High',
#        'Low', 'High', 'Low', 'Low', 'High', 'Low', 'Low', 'Low', 'Low',
#        'High', 'Low', 'Low', 'High', 'High', 'High', 'High', 'Low',
#        'High', 'Low', 'High', 'Low', 'Low', 'Low', 'High', 'High', 'High',
#        'High', 'Low', 'Low', 'High', 'High', 'Low', 'High', 'High',
#        'High', 'High', 'High', 'High', 'High', 'Low', 'High', 'High',
#        'Low', 'Low', 'High', 'Low', 'High', 'High', 'High', 'High',
#        'High', 'Low', 'Low', 'Low', 'Low', 'Low', 'Low', 'Low', 'Low',
#        'Low', 'Low', 'Low', 'High', 'Low', 'High', 'High', 'High', 'High',
#        'High', 'Low', 'High', 'Low', 'High', 'Low', 'Low', 'High', 'Low',
# ...

# %%
ypred=model.predict(X_test)

# %%
model.score(X_test, y_test)
# Out:
# 0.9925373134328358

# %% [markdown]
# # SAVING THE MODEL

# %%
# Pickle model
#pd.to_pickle(model,r'C:\Users\TECHNICIAN\Desktop\CANCER-END-END\django_cancer_ml\new_model.pickle')
pd.to_pickle(model,r'C:\Users\TECHNICIAN\Desktop\CANCER-END-END\django_cancer_ml\mysite\new_model.pickle')
# Unpickle model
#model = pd.read_pickle(r'c:\Users\azander\Downloads\new_model.pickle')

#model = pd.read_pickle(r'C:\Users\TECHNICIAN\Desktop\CANCER-END-END\django_cancer_ml\new_model.pickle')

model = pd.read_pickle(r'C:\Users\TECHNICIAN\Desktop\CANCER-END-END\django_cancer_ml\mysite\new_model.pickle')
# read a pickle pd.read_pickle('model.pkl')

# Take input from user
Age = float(input("Enter your Age"))
air_pollution = float(input("Enter air_pollution: "))
alcohol_use = float(input("Enter   alcohol_use: "))
genetic_risk = float(input("Enter genetic_risk: "))
chronic_lung_disease = float(input("Enter chronic Lung Disease: "))

result = model.predict([[Age,air_pollution,alcohol_use,genetic_risk,chronic_lung_disease]])  # input must be 2D array
print(result)
# Out:
# Enter your Age3
# Enter air_pollution: 3
# Enter   alcohol_use: 23
# Enter genetic_risk: 3
# Enter chronic Lung Disease: 2
# ['High']
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
